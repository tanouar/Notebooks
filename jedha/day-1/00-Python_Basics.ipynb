# %% [markdown]
# # Python Basics Reminder
#
# ## What you will learn in this course 🧐🧐
# Python will be one of your main tool for programming. It is an easy to learn, powerful programming language. It provides high-level **data structures** and a simple but effective approach to **object-oriented programming**. Thanks to its readable syntax, **dynamic typing**, and interpreted runtime, it excels at **scripting** and rapid application development across platforms.

# %% [markdown]
# In this lecture, we will review the basics of Python. We will cover the following topics:
#
# - Fundamental concepts of **variables**
# - Essential **methods** for manipulating different data type
#
#
# <Note type="important">
#
# At the beginning of this course, we’ll often use **[Google Colab](https://colab.research.google.com/)**.  It’s perfect to get started quickly: no installation, everything runs in your browser, and you can focus on Python rather than setup.
#
# However, later in the module you will need a **real IDE (Integrated Development Environment)** installed on your machine to work like a real developer and build more serious projects. We recommend using **[VS Code](https://code.visualstudio.com/)** for this course.
# You will find the installation instructions in the *setup* section of this module.
#
# You should also know that there are now **AI-augmented IDEs**:
#
# - **VS Code + [GitHub Copilot](https://github.com/features/copilot)**): AI helps you complete code, write tests, or refactor functions directly in your editor.
# - **AI-first IDEs** like **[Cursor](https://www.cursor.so/)** or **[Windsurf](https://windsurf.ai/)** (based on VS Code): they go further and can understand your whole project, propose larger changes, or generate files from natural language.
# - **[JetBrains IDEs](https://www.jetbrains.com/)** (PyCharm, IntelliJ, etc.) now also embed an **AI Assistant**.
#
# AI tools should be used to **assist** you, not replace your own understanding of coding. Thus, even though these tools are very powerful, they are not perfect and sometimes generate incorrect code. Always review the generated code carefully and test it thoroughly.
#
# </Note>

# %% [markdown]
# ## City of Paris
# In order to use Python, you will step in as a Data Analyst for the City of Paris. You have to build a small extract of resident records. By using Python you will answer practical question city teams care about. We will compute the record for one resident to a small data collection.

# %% [markdown]
# ## Variables
# One of the first things, that you have to learn is a **variable** where it is a named container that **stores data** (text, number, etc.) in computer memory. Once the variable is compute, its data can be access everywhere. Unlike [static-typed languages](https://developer.mozilla.org/en-US/docs/Glossary/Static_typing#:~:text=A%20statically%2Dtyped%20language%20is,not%20indicate%20their%20variable%20types.), Python variables can change type **dynamically**. The type of the variable is inferred based on the value assigned. It means that it **recognizes** the store data by itself.

# %%
city_name = "Paris"
ZIP = "75001"

# %% [markdown]
# We initialize our variables like this ```variable = data```, the first one is a **text**, or **characters** store in city name (It is called a string but we will deep dive into that notion later), and the last one is a **number** (called a integer) where we put in the variable named arrondissement. You have to remember the variable is where you store your data and **not the data itself**.
#
# We have seen our first initialization or assignment. Based on the type of data that you used you can do many **manipulation** such as calculation, **rewriting** text or even **reassigning** it

# %% [markdown]
# In Python, the variable can **change**. Imagine that you have decided to change the name of the city or moved to a diffirent district. So in order to reassign our data, you simply have to retake the variable name and reassign with the new data.

# %%
# Reassignment
city_name = "Marseille"
ZIP = "13001"

# %% [markdown]
# By doing so, the variable's data is **overwritten** with the new one and the previous data is **deleted**.

# %% [markdown]
# <Note type="note">
#
# Knowing how to name your variables is important to make your code more readable. Here are some good practices:
#
# - **Descriptive names**: ```total_residents``` instead of ```tr```
# - **Snake_case**: ```average_income_per_resident``` not averageIncomeperResident
# - **Avoid reserved words**: Don't use ```class```, ```def```, etc.
# - **Constants**: Use ALL_CAPS for constants ```ZIP``` = 75003
# - **Consistent naming**: Use the same naming convention for all variables in a function
#
# </Note>

# %% [markdown]
# ### Print a variable
# Once we have store our data. How can we see the **output** of it ?.
# In Python there are some existing **functions** given such as [```print()```](https://docs.python.org/3/library/functions.html#print) function which shows values; f-strings embed variables into **readable text**. It matters because it can **display** the output of our data, code. It prints the data even if the type differ.

# %% [markdown]
# Let's try to **display** a random resident:  ```first_name```,```last_name```, ```age```, ```city```

# %%
first_name = "Paul"
last_name = "Pratt"
age = 28

# %%
print(first_name)
print(last_name)
print(age)
print(city_name)
# Out:
# Paul
# Pratt
# 28
# Marseille

# %% [markdown]
# <Note type="note">
#
# See after our reassignment, the city name changed to **Marseille** and not **Paris**. So be careful by **reusing** the same name of variable. You can overwrite the original data.
#
# </Note>

# %% [markdown]
# Moreover, ```print()```can be formatted in the **structure** we want. The ```f``` or ```F``` in front of ```""```, look for the **values**, **expressions** or **instance** inside {} and substitute them with the variables values or results if exists.
# Here's the format that we can to display:
#
# ```Paul Pratt, 28 ans, Marseille"```

# %%
# Let's print the variables
print(f"{first_name} {last_name}, {age} ans, {city_name}")
print(first_name + " " + last_name + ", " + str(age) + " ans, " + city_name)
# Out:
# Paul Pratt, 28 ans, Marseille
# Paul Pratt, 28 ans, Marseille

# %% [markdown]
# ## PEP 8 Style Guide

# %% [markdown]
# Python has PEP 8, the official style guide that ensures code is consistent and readable across all Python projects. Following these conventions makes your code professional and maintainable.
#
# PEP 8 defines how we should name our variables, functions, and other elements:

# %%
# GOOD - Following PEP 8
resident_name = "Paul Pratt"  # snake_case for variables
MAX_DISTRICTS = 20            # UPPER_CASE for constants
total_income = 3120.75        # descriptive names

# BAD - Not following PEP 8
residentName = "Paul Pratt"   # camelCase (wrong for Python)
n = "Paul Pratt"              # too short, unclear
TOTAL_income = 3120.75        # mixed case styles

# %% [markdown]
# In order to keep your code readable, you also need to limit the line length, making it more clear and precise.

# %%
# GOOD - Lines under 79 characters
district_message = (
    f"Resident {first_name} {last_name} from district {ZIP} "
    f"has registered with income {total_income}"
)

# BAD - Line too long
district_message = f"Resident {first_name} {last_name} from district {ZIP} has registered with income {total_income} and requires processing"

# %% [markdown]
# ## Data Types
# Now that we can **name** and **store** values with variables, let's see what data types those values actually are because in Python’s dynamic typing, the type is based on the value (**not the variable**) and dictates what operations make sense.
# Python have many **data types**. In this section, we will see the most common ones.
# A data type defines the **kind of value** a variable can hold and the **operations** that can be performed on it.
# Python has these core types:
#
# 1. **Numeric Data Types**
#     - int: Integer
#     - float: Floating-point number
#
# 2.  **Two built-in values**
#     - bool: Boolean
# 3. **Sequence Data Types**
#     - str: String
#     - list: List
#     - tuple: Tuple
#     - dict: Dictionary

# %% [markdown]
# <Note type="warning">
#
# We can not **mix** data types in Python. For example, we can not add a **string** and an **integer**. But there is a way to **transform** the data, that we will see further in this lecture.
# ```python
# name = first_name + age
# ```
# The output will display an error
# ```python
# TypeError: can only concatenate str (not "int") to str
# ```
# </Note>

# %% [markdown]
# ### Integer
# The first common data type is Integer. It is a whole number, positive or negative, **without decimals**, of unlimited length. It can take any form such IDs, and ages. Many KPIs and rules depend on **integer arithmetic**.
#
# We take retake the age of our resident and perform some mathematical operations:

# %%
print(age + 1)    # 29
print(age - 5)    # 23
print(age * 2)    # 56
print(age / 10)  # 2 (decades)
print(age % 10)   # 8 (years after decade)
# Out:
# 29
# 23
# 56
# 2.8
# 8

# %% [markdown]
# ### Float
# Next data type is Float. It is a data type that is a number, positive or negative, **containing one or more decimals**. It can be for instance money and ratios.
#
# Here are some operations that you can perform with floats, we want to add a 5% of the income and divide to 1000:

# %%
income = 3120.75
print(income * 1.05)   # +5%
print(income / 1000)   # in thousands
# Out:
# 3276.7875000000004
# 3.12075

# %% [markdown]
# ### Booleans
# Boolean are implemented as a **subclass of integers**. There are only two values booleans ```True``` and ```False```. It is used to do **comparison** between two values. So the comparison is evaluated, Python will return the **Boolean answer**.
# It also has another purpose for **conditions** and **loop**, we will see it in the next lecture.

# %% [markdown]
# <Note type="note">
#
# Boolean are consider as intergers because the value of ```True```and ```False``` are either 1 or 0. For example you can add ```True```and ```True```and you will get 2
# ```Python
#     A = True + True
#     print(A)
#     2
# ```
# </Note>

# %% [markdown]
# With our resident Paul, we know his age and his location. Imagine that we want to see if his age is below 30 or the name of the city.
# Let's do a comparison on his age and the city name, imagine we want to know if he is under 30 and if the city name is Paris:

# %%
print(age < 30)

city_name = "Marseille"

print(city_name == "Paris")
# Out:
# True
# False

# %% [markdown]
# <Note type="note">
#
# You can see that in the print they are some **operators**. They are used to do **comparison**, for instance the first one is to see if it is **inferior than** the value and the last one is to see if it is **equal to** the value. We will see more operators in the next lecture
# </Note>

# %% [markdown]
# ### String
# String is a **sequence of characters** enclosed by either single **quotation marks**, or double quotation marks. It can include letters, symboles, numbers or spaces. Strings are used for **text handling** and **manipulation**.
#
# Let's take back our first resident. You have already put his name in variables, but we will try to made into one.
# There are some given functions like ```print()``` called **methods**  that you can use with strings in order to get more information on the text and format. You can used it by doing ```variable```**.methods()**

# %% [markdown]
# As we know, we have two variables for the name ```first_name``` and ```last_name```.

# %%
print(first_name)
print(last_name)
# Out:
# Paul
# Pratt

# %% [markdown]
# If we want to put the two variables **together**, it's simple. You can add the String with the operator ```+```. This is called [**String Concatenation**](https://docs.python.org/3/library/string.html).

# %%
full_name = (first_name + " " + last_name)
print(full_name)

print(full_name.upper())
# Out:
# Paul Pratt
# PAUL PRATT

# %% [markdown]
# We added another string in order to make the **separation** between the names otherwise. It would look like this ```PaulPratt```.
#
# Once we have the full name, let's try to use the some **methods** to gather more information on the string.

# %% [markdown]
# <Note type="note">
#
# A method is a **function** that is associated with a **object** or **class**. You will have more detail on that in the next lecture.
#
# </Note>

# %% [markdown]
# The String methods returns **new values** with the changed attributes however they do not change the **original string**.

# %% [markdown]
# | Methods	            | Purpose	                                                    |                               |
# |-----------------------|---------------------------------------------------------------|-------------------------------|
# |```.lower()```	        | Converts all uppercase characters in lowercase	            | ```Paris → paris```           |
# |```.upper()```	        | Converts all lowercase characters in uppercase	            | ```paris → Paris ```          |
# |```.startswith()```	| Returns True if a String starts with the specified value      | ```"P" in Paris → True```     |
# |```.endswith```	    | Returns True if a String ends with the specified value	    | ```"S" in  Paris → True```    |
# |```.count()```	        | Returns the number of occurences of a substring in the string	| ```"A" in Paris → 1```        |
# |```.replace()```	    | Replaces all occurences of a substring with another substring | ``` Paris → Marseille```      |

# %% [markdown]
# Let's try those methods on Paul.

# %%
print(full_name.lower())
# Out:
# paul pratt

# %%
print(full_name.upper())
# Out:
# PAUL PRATT

# %%
print(full_name.startswith("P"))
# Out:
# True

# %%
print(full_name.endswith("S"))
# Out:
# False

# %%
print(full_name.count('P'))
# Out:
# 2

# %%
print(full_name.replace("Pratt", "Dupont"))
# Out:
# Paul Dupont

# %% [markdown]
# Previously said, those methods will **not change** the original variables. Let's verify it.

# %%
print(full_name)
# Out:
# Paul Pratt

# %% [markdown]
# ### Define a data type
# Now remember that in **Python’s dynamic typing** we do not **declare** types up front the value **carries** the type, and we often need to **convert** to the right type (numbers, booleans, dates) before we can **compute** with it.
# Once you have initialize your **variables**, you have put your data such as number or text even keyword like ```True``` or ```False```.

# %% [markdown]
# Let's verify our first resident:

# %% [markdown]
# To know the **type** of a variable, you can use the [```type()```](https://docs.python.org/3/library/functions.html#type) function. It is also an existing functions in python.
#
# ```python
# print(type(text))
# ```
#
# ```<class 'str'>```

# %%
# Let's see the type of the variables  
print(type(full_name))
print(type(age))
#print(type(income))
type(city_name)
# Out:
# <class 'str'>
# <class 'int'>
# str

# %% [markdown]
# ### Convert a data type to another
# We just created values of **specific types** (ints, floats, strings, …); next we’ll convert between **types** because in real data, values often arrive as text and must be **cast** before we can compute, compare, or sort correctly.
#
# **Casting** is creating a **new value** of a **target type** from an existing values.
#
# Once you know the **type of the variable**, you can **convert** a data type to another.
# For example, you need to convert a string to an integer to perform a mathematical operation.
# We can use the following **functions** to convert a data type to another:
#
# - [**int()**](https://docs.python.org/3/library/functions.html#int): Convert to integer

# %% [markdown]
# So here, we have the income of our resident which is a **float**. ```int()``` lets us treat a **value** as a whole number either by **dropping** the cents from a float income or by turnin a **numeric text** like "42" into the **integer** 42

# %%
print(int(income))  
print(int(ZIP))

income = str(income)
# Out:
# 3120
# 13001

# %% [markdown]
# - [**float()**](https://docs.python.org/3/library/functions.html#float): Convert to floating-point number

# %% [markdown]
# When numbers need decimals for **averages** or rates, ```float()``` converts **integers** or numeric **strings** (e.g., "3120.75") into **floating-point** values so we can compute totals and ratios correctly.

# %% [markdown]
# Let's do a **ratio** from a string. Imagine you have received a income value but it was not written on the **desired type**.

# %%
str_income = "2199.50"
number_residents = 4

total_income = float(str_income)
avg_per_person = total_income / float(number_residents)

print(total_income)
print(avg_per_person)
# Out:
# 2199.5
# 549.875

# %% [markdown]
# - [**str()**](https://docs.python.org/3/library/stdtypes.html#str): Convert to string

# %% [markdown]
# For labels and messages, ```str()``` turns **values** into **text useful** to build **readable outputs** (reports, filenames) from numbers or dates without **changing** the data itself.

# %% [markdown]
# Let's work with Paul, he is our first resident, so let's to store his informations such as his age, his income in a line. We want this type of structure:
# ```Age: 28 and Income: 3120.75```

# %%
line = "Age: " + str(age) + " and Income: " + str(income) 
print(line)
print(type(age))
# Out:
# Age: 28 and Income: 3120.75
# <class 'int'>

# %% [markdown]
# Let's verify its type in order to confirm that it is a real string

# %%
print(type(line))
# Out:
# <class 'str'>

# %% [markdown]
# - [**bool()**](https://docs.python.org/3/library/functions.html#bool): Returns the boolean value of a specified values.

# %% [markdown]
# bool() function evaluates the **truthness** or **falseness** of a given value and returns True or False.
# For our residents, we can use booleans for a **yes/no flags** (e.g., is eligible, has children)

# %% [markdown]
# Let's try on the has_children values, consider that Paul does not have children and a second resident Alexis has 2 children.

# %%
paul_children = 0
print(bool(paul_children))
# Out:
# False

# %%
alexis_children = 2
print(bool(alexis_children))
# Out:
# True

# %% [markdown]
# ## Check Type
#
# When working with users or external data, it's important to **check the type** of your variables before using them. Python gives you two useful tools for this: `input()` and `isinstance()`.
#
# ### Get data from the user
#
# The `input()` function lets you ask the user to type something.
#
# ```python
# city = input("Enter your city: ")
# print(city)
# ```
#
# By default, `input()` always returns a **string**, even if the user types a number.
#
# To use the value as a number, you must convert it:
#
# ```python
# age = input("Enter your age: ")     # User types 30 → still a string
# age = int(age)                      # Convert to integer
# print(age + 1)                      # Now it works!
# ```
#
# ### Check the data type
#
# If you're not sure what type a variable has, use `isinstance()`:
#
# ```python
# print(isinstance(age, int))       # True
# print(isinstance(city, str))      # True
# ```
#
# You can also check against multiple types:
#
# ```python
# print(isinstance(age, (int, float)))  # Is age a number?
# ```
#
# This helps avoid errors before doing operations. Always check before converting or calculating. These two tools: `input()` for collecting data and `isinstance()` for checking it—are essential when your program starts interacting with real people and unpredictable inputs.

# %%
city = input("Enter your city: ")

# %%
print(city)
# Out:
# Paris

# %% [markdown]
# ## Resources 📚📚

# %% [markdown]
# - [The Python Prepworks you already did](https://app.jedha.co/track/introduction-to-python-for-data-science)
# - [Python Tutorial on Data Structures](https://docs.python.org/3/tutorial/datastructures.html)
