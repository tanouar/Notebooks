# %%
pip install wbdata
# Out:
# ...
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached regex-2024.11.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# ...
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 6.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 14.9 MB/s eta 0:00:00
# Using cached regex-2024.11.6-cp312-cp312-macosx_11_0_arm64.whl (284 kB)
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.9.0
#     Uninstalling tabulate-0.9.0:
#       Successfully uninstalled tabulate-0.9.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wbdata
import pandas as pd
import datetime

# %%
# Récupérer les données pour un indicateur spécifique
import wbdata

# Récupérer les données pour un indicateur spécifique pour une année donnée
data = wbdata.get_data("SL.EMP.TOTL.SP.ZS", country="EU")

pd.DataFrame(data)



#SL.EMP.WORK.ZS        Wage and salaried workers, total (% of total employment) (modeled ILO estimate)
# Out:
#                                             indicator  \
# 0   {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
# 1   {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
# 2   {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
# 3   {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
# 4   {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
# ..                                                ...
# 60  {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
# 61  {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
# 62  {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
# 63  {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
# 64  {'id': 'SL.EMP.TOTL.SP.ZS', 'value': 'Employme...
#
#                                     country countryiso3code  date      value  \
# 0   {'id': 'EU', 'value': 'European Union'}             EUU  2024  54.060600
# 1   {'id': 'EU', 'value': 'European Union'}             EUU  2023  54.177729
# 2   {'id': 'EU', 'value': 'European Union'}             EUU  2022  53.956543
# ...
