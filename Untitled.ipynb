# %%
import pandas as pd

# %%
df = pd.read_csv('merged_filtered_dataset')
df
# Out:
#     Country name  year  Life Ladder  Logged GDP per capita  Social support  \
# 0    Afghanistan  2013        3.572                  7.725           0.484
# 1    Afghanistan  2014        3.131                  7.718           0.526
# 2    Afghanistan  2015        3.983                  7.702           0.529
# 3    Afghanistan  2016        4.220                  7.697           0.559
# 4    Afghanistan  2017        2.662                  7.697           0.491
# ..           ...   ...          ...                    ...             ...
# 625     Zimbabwe  2013        4.690                  7.985           0.799
# 626     Zimbabwe  2014        4.184                  7.991           0.766
# 627     Zimbabwe  2015        3.703                  7.992           0.736
# 628     Zimbabwe  2016        3.735                  7.984           0.768
# 629     Zimbabwe  2017        3.638                  8.016           0.754
#
# ...

# %%
df['Country_ID'] = pd.factorize(df['Country name'])[0]
df
# Out:
#     Country name  year  Life Ladder  Logged GDP per capita  Social support  \
# 0    Afghanistan  2013        3.572                  7.725           0.484
# 1    Afghanistan  2014        3.131                  7.718           0.526
# 2    Afghanistan  2015        3.983                  7.702           0.529
# 3    Afghanistan  2016        4.220                  7.697           0.559
# 4    Afghanistan  2017        2.662                  7.697           0.491
# ..           ...   ...          ...                    ...             ...
# 625     Zimbabwe  2013        4.690                  7.985           0.799
# 626     Zimbabwe  2014        4.184                  7.991           0.766
# 627     Zimbabwe  2015        3.703                  7.992           0.736
# 628     Zimbabwe  2016        3.735                  7.984           0.768
# 629     Zimbabwe  2017        3.638                  8.016           0.754
#
# ...
